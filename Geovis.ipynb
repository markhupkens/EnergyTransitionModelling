# %%
import geopandas 
from shapely.geometry import Point, Polygon
import descartes
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load example data
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# # Reproject to Mercator (after dropping Antartica)
world = world[(world.name != "Antarctica") & (world.name != "Fr. S. Antarctic Lands")]

# world = world.to_crs({'init': 'epsg:3395'}) # world.to_crs(epsg=3395) would also work

# In [7]: ax = world.plot()

In [8]: ax.set_title("Mercator");
ax = world.plot()

# %%
world.head()
# Out:
#       pop_est      continent                  name iso_a3  gdp_md_est  \
# 0  28400000.0           Asia           Afghanistan    AFG     22270.0
# 1  12799293.0         Africa                Angola    AGO    110300.0
# 2   3639453.0         Europe               Albania    ALB     21810.0
# 3   4798491.0           Asia  United Arab Emirates    ARE    184300.0
# 4  40913584.0  South America             Argentina    ARG    573900.0
#
#                                             geometry
# 0  POLYGON ((6813956.989691116 4227673.561898688,...
# 1  (POLYGON ((1817460.822852346 -651055.117933030...
# 2  POLYGON ((2292095.859226788 5110825.730490864,...
# 3  POLYGON ((5741805.753758118 2765811.384651244,...
# 4  (POLYGON ((-7291426.646959423 -7365665.1311332...

# %%
fig, ax = plt.subplots(figsize=(20,10))

world = world[(world.pop_est>0) & (world.name!="Antarctica")]

world['gdp_per_cap'] = world.gdp_md_est / world.pop_est

world.plot(column='gdp_per_cap', ax=ax, legend=True, cmap='OrRd', scheme='quantiles')

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax = plt.subplots(1, 1)

divider = make_axes_locatable(ax)

cax = divider.append_axes("right", size="5%", pad=0.1)

world.plot(column='pop_est', ax=ax, legend=True, cax=cax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-265c2d7fc948> in <module>
#       7 cax = divider.append_axes("right", size="5%", pad=0.1)
#       8
# ----> 9 world.plot(column='pop_est', ax=ax, legend=True, cax=cax)
#
# ~\Anaconda3\lib\site-packages\geopandas\geodataframe.py in plot(self, *args, **kwargs)
#     532         from there.
#     533         """
# --> 534         return plot_dataframe(self, *args, **kwargs)
#     535
#     536     plot.__doc__ = plot_dataframe.__doc__
#
# ~\Anaconda3\lib\site-packages\geopandas\plotting.py in plot_dataframe(df, column, cmap, color, ax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, **style_kwds)
#     466     if not polys.empty:
#     467         plot_polygon_collection(ax, polys, values[poly_idx],
# --> 468                                 vmin=mn, vmax=mx, cmap=cmap, **style_kwds)
# ...

# %%
gdf2 = gpd.read_file('data/geodata/gem_2018/gem_2018.shp')
gdf2.head()
# Out:
#   GM_CODE     GM_NAAM WATER   OAD  STED  AANT_INW  AANT_MAN  AANT_VROUW  \
# 0  GM0003  Appingedam   NEE  1051     3     11801      5751        6050
# 1  GM0005       Bedum   NEE   685     4     10475      5235        5240
# 2  GM0009    Ten Boer   NEE   372     5      7292      3616        3676
# 3  GM0010    Delfzijl   NEE   677     4     24864     12475       12389
# 4  GM0014   Groningen   NEE  3456     1    202810    101299      101511
#
#    P_00_14_JR  P_15_24_JR  ...  P_HH_M_K  GEM_HH_GR  P_WEST_AL  P_N_W_AL  \
# 0          15          10  ...        31        2.1          7         7
# 1          16          11  ...        36        2.3          4         3
# 2          18          12  ...        39        2.4          4         3
# 3          14          11  ...        31        2.1          8        10
# 4          12          24  ...        18        1.6         12        12
#
#    P_MAROKKO  P_ANT_ARU  P_SURINAM  P_TURKIJE  P_OVER_NW  \
# ...

# %%
fig, ax = plt.subplots(1,1)
gdf2.plot(alpha=0.8, ax=ax, edgecolor='k')
gdf.plot(ax=ax)

# %%
# load example data
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# Check original projection
# (it's Platte Carre! x-y are long and lat)
world.crs


# Visualize
In [3]: ax = world.plot()

In [4]: ax.set_title("WGS84 (lat/lon)");

# Reproject to Mercator (after dropping Antartica)
In [5]: world = world[(world.name != "Antarctica") & (world.name != "Fr. S. Antarctic Lands")]

In [6]: world = world.to_crs({'init': 'epsg:3395'}) # world.to_crs(epsg=3395) would also work

In [7]: ax = world.plot()

In [8]: ax.set_title("Mercator");
# Out:
# {'init': 'epsg:4326'}

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
world.crs
# Out:
# {'init': 'epsg:4326'}

# %%
ax = world.plot()

# %%
ax.set_title("WGS84 (lat/lon)")
# Out:
# Text(0.5, 1.0, 'WGS84 (lat/lon)')

# %%
world = world[(world.name != "Antarctica") & (world.name != "Fr. S. Antarctic Lands")]

# %%
ax = world.plot()

# %%
world = world.to_crs({'init': 'epsg:3395'}) # world.to_crs(epsg=3395) would also work
ax = world.plot()

# %%
gdf.to_crs({'init': 'epsg:28992'})
gdf2.to_crs({'init': 'epsg:28992'}) # used to be {'init': 'epsg:28992'}
# Out:
#     GM_CODE                         GM_NAAM WATER       OAD      STED  \
# 0    GM0003                      Appingedam   NEE      1051         3
# 1    GM0005                           Bedum   NEE       685         4
# 2    GM0009                        Ten Boer   NEE       372         5
# 3    GM0010                        Delfzijl   NEE       677         4
# 4    GM0014                       Groningen   NEE      3456         1
# 5    GM0015                      Grootegast   NEE       231         5
# 6    GM0017                           Haren   NEE       883         4
# 7    GM0022                            Leek   NEE       734         4
# 8    GM0024                       Loppersum   NEE       213         5
# 9    GM0025                           Marum   NEE       339         5
# 10   GM0034                          Almere   NEE      1584         2
# 11   GM0037                     Stadskanaal   NEE       839         4
# ...

# %%
fig, ax = plt.subplots(1,1)
gdf2.plot(alpha=0.8, ax=ax, edgecolor='k')
gdf.plot(ax=ax)
